# %% [markdown]
# <a href="https://colab.research.google.com/github/kimjunyeop1/project1/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.range(0, 2)
y = x**2+sin(3x+7)
plt.plot(x, y)
plt.show()
# Out:
#   File "<ipython-input-5-5b8a0ba02a5a>", line 5
#     y = x**2+sin(3x+7)
#                   ^
# SyntaxError: invalid syntax

# %%
def f(x):
  return x**2 + np.sin(3x+7)

f(1)
# Out:
#   File "<ipython-input-15-a5f4cccce8fc>", line 2
#     return x**2 + np.sin(3x+7)
#                           ^
# SyntaxError: invalid syntax

# %%
from IPython.utils.path import target_outdated
import seaborn as sns
target_caffeine=
# Out:
#   File "<ipython-input-17-3a2fa63501a5>", line 3
#     target_caffeine=
#                     ^
# SyntaxError: invalid syntax

# %%
from google.colab import files
myfile = files.upload()
import pandas as pd

df = pd.read_csv('caffeine.csv')

df
# Out:
#      <input type="file" id="files-46803533-4a3a-4b3f-9586-48fec870a97f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46803533-4a3a-4b3f-9586-48fec870a97f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set(rc={'figure.dpi':200})
sns.set(rc={'figure.figsize':(6,3)})

sns.scatterplot(x='Volume (ml)', y="Calories", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set(rc={'figure.dpi':200})
sns.set(rc={'figure.figsize':(6,3)})

sns.scatterplot(x='Caffeine (mg)', y="Calories", data=df, hue='type')

# %%
import pandas as pd
import seaborn as sns

sns.set_theme()
sns.set(rc={'figure.dpi':200})
sns.set(rc={'figure.figsize':(6,3)})

sns.scatterplot(x='Volume (ml)', y="Caffeine (mg)", data=df, hue='type')
